# %% [markdown]
# ## Predict Product Prices
#
# ## Evaluate fine-tuned open source llama-3.1-8B model

# %%
# !pip install -q datasets peft requests torch bitsandbytes transformers trl accelerate sentencepiece matplotlib
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 37.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 21.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 17.9 MB/s eta 0:00:00

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "sahidul-hf1"

# Finetuned model details from Huggingface
RUN_NAME = "2025-03-02_11.39.19"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = "676c5257c020bcdcb95aae11e3e524f929bbf6b5"
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Data
DATASET_NAME = f"{HF_USER}/pricer-data"

# Hyperparameters for QLoRA
QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color
GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
# Load dataset from Huggingface

dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/412 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/9.72M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/771k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nSetpower Insulated Protective Cover for AJ30 Portable Refrigerator Freezer, suitable for AJ30 Only\nInsulation & Waterproof well-made insulation could save battery power and improve cooling efficiency by preventing cold air from flowing away. Durable and Foldable with its oxford cloth outer layer, it's durable and protects your portable refrigerator from scratches and dust. Expanded Bag for Accessories two expanded bags on its side, expand space to store the other accessories. Great Ventilation a hollowed design for positions of vents doesn't affect the ventilation. Attention this insulated cover is ONLY suitable for SetPower AJ30 portable refrigerator. FIT TO AJ30 ONLY. Brand Name Setpower, Model Info AJ30 COVER, model number AJ30 COVER, Installation Type Freestanding, Part AJ30 cover, Special Features Portable, Color\n\nPrice is $",
#  'price': 65.99}

# %% [markdown]
# ## Load the Tokenizer and Model

# %%
# Pick 8 bits or 4 bits quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
# Function for extracting only the price from string

def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
# An improved prediction function takes a weighted average of the top 3 choices
# Taking the top 3 probabilities token from softmax layer and average it price

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
# Tester class.
# Takes a test datapoint and predict in formatted output

class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
# Model inference
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $22.12 Truth: $65.99 Error: $43.86 SLE: 1.13 Item: Setpower Insulated P...
# 2: Guess: $10.95 Truth: $9.68 Error: $1.27 SLE: 0.01 Item: TUAIC Refrigerator D...
# 3: Guess: $49.41 Truth: $155.98 Error: $106.57 SLE: 1.29 Item: Kegco Secondary Regu...
# 4: Guess: $11.59 Truth: $5.59 Error: $6.00 SLE: 0.42 Item: Refrigerator Door Sp...
# 5: Guess: $21.64 Truth: $98.40 Error: $76.76 SLE: 2.19 Item: Ice-O-Matic Float Va...
# 6: Guess: $29.66 Truth: $54.99 Error: $25.33 SLE: 0.36 Item: Wireless Temperature...
# 7: Guess: $10.96 Truth: $5.71 Error: $5.25 SLE: 0.33 Item: 3Inch Thermometer Hy...
# 8: Guess: $10.96 Truth: $9.53 Error: $1.43 SLE: 0.02 Item: GE GE Timer Knob Ass...
# 9: Guess: $10.91 Truth: $11.24 Error: $0.33 SLE: 0.00 Item: newlifeapp Dryer Lin...
# 10: Guess: $22.45 Truth: $12.88 Error: $9.57 SLE: 0.28 Item: Away NV350 NV351 NV3...
# 38: Guess: $24.48 Truth: $23.99 Error: $0.49 SLE: 0.00 Item: Overbest Replacement...
# 39: Guess: $19.00 Truth: $6.99 Error: $12.01 SLE: 0.84 Item: Fill 'n Brew Individ...
# 40: Guess: $21.72 Truth: $24.99 Error: $3.27 SLE: 0.02 Item: Maytag EDR7D1 Compar...
# 41: Guess: $10.97 Truth: $11.61 Error: $0.64 SLE: 0.00 Item: Coffee Filters - Nat...
# 42: Guess: $259.50 Truth: $949.00 Error: $689.50 SLE: 1.67 Item: EdgeStar 20 Inch Wid...
# 43: Guess: $62.44 Truth: $74.00 Error: $11.56 SLE: 0.03 Item: Bosch Door Lower Bin...
# 44: Guess: $18.00 Truth: $22.05 Error: $4.05 SLE: 0.04 Item: Samsung Switch Door-...
# 45: Guess: $128.50 Truth: $284.00 Error: $155.50 SLE: 0.62 Item: Jenn air Stove Cartr...
# 46: Guess: $56.25 Truth: $91.78 Error: $35.53 SLE: 0.23 Item: Whole Parts Burner G...
# 47: Guess: $26.38 Truth: $45.20 Error: $18.83 SLE: 0.27 Item: DEFLECTO SK8WF Supur...
# 48: Guess: $10.92 Truth: $8.69 Error: $2.23 SLE: 0.04 Item: Supco RR109 Receptac...
# 49: Guess: $11.62 Truth: $16.18 Error: $4.56 SLE: 0.10 Item: Dryer Lint Screen Fi...
# 50: Guess: $10.00 Truth: $6.50 Error: $3.50 SLE: 0.15 Item: Replacement Light Bu...
# 51: Guess: $10.98 Truth: $32.21 Error: $21.23 SLE: 1.04 Item: ForeverPRO Drum Ligh...
# 52: Guess: $18.47 Truth: $15.39 Error: $3.08 SLE: 0.03 Item: Highcraft Dishwasher...
# 53: Guess: $20.05 Truth: $17.99 Error: $2.06 SLE: 0.01 Item: and Stove Burner Dri...
# 54: Guess: $21.73 Truth: $26.99 Error: $5.26 SLE: 0.04 Item: ReplacementBrand Com...
# 55: Guess: $9.95 Truth: $11.99 Error: $2.04 SLE: 0.03 Item: 2-Pack 341241 Dryer ...
# 56: Guess: $10.91 Truth: $44.46 Error: $33.55 SLE: 1.79 Item: Power Nut Kit - Comp...
# 57: Guess: $11.72 Truth: $15.99 Error: $4.27 SLE: 0.08 Item: Stovetop Extender Ov...
# 58: Guess: $90.38 Truth: $129.99 Error: $39.62 SLE: 0.13 Item: COSVALVE Portable Wa...
# 59: Guess: $22.62 Truth: $24.99 Error: $2.36 SLE: 0.01 Item: AlaSou Washer Dustpr...
# 60: Guess: $16.05 Truth: $27.38 Error: $11.33 SLE: 0.26 Item: Honeywell Pad for He...
# 61: Guess: $16.66 Truth: $16.95 Error: $0.29 SLE: 0.00 Item: HQRP 2-Pack Wick Fil...
# 62: Guess: $11.01 Truth: $10.82 Error: $0.19 SLE: 0.00 Item: Whirlpool Pad Washer...
# 63: Guess: $11.66 Truth: $19.00 Error: $7.34 SLE: 0.21 Item: Durable Disposable E...
# 91: Guess: $29.30 Truth: $33.69 Error: $4.39 SLE: 0.02 Item: Frigidaire Surface B...
# 92: Guess: $19.03 Truth: $12.99 Error: $6.04 SLE: 0.13 Item: TooCust Milk Frothin...
# 93: Guess: $19.02 Truth: $12.99 Error: $6.03 SLE: 0.13 Item: Premium Vials 38 x 2...
# 94: Guess: $9.09 Truth: $10.98 Error: $1.89 SLE: 0.03 Item: Washer Door Lid Swit...
# 95: Guess: $21.61 Truth: $26.44 Error: $4.83 SLE: 0.04 Item: Aqua Fresh Replaceme...
# 96: Guess: $18.41 Truth: $16.99 Error: $1.42 SLE: 0.01 Item: InterDesign Covered ...
# 97: Guess: $18.34 Truth: $25.25 Error: $6.91 SLE: 0.09 Item: Upgrade Gas Range Ov...
# 98: Guess: $14.22 Truth: $11.88 Error: $2.34 SLE: 0.03 Item: Washing Machine Inne...
# 99: Guess: $24.78 Truth: $28.99 Error: $4.21 SLE: 0.02 Item: Maxmartt 100mm Vent ...
# 100: Guess: $11.73 Truth: $23.12 Error: $11.39 SLE: 0.41 Item: Upgraded Lifetime Ap...
# 101: Guess: $21.67 Truth: $52.97 Error: $31.30 SLE: 0.75 Item: Whirlpool Sensor for...
# 102: Guess: $29.62 Truth: $25.99 Error: $3.64 SLE: 0.02 Item: Wintact Digital Temp...
# 103: Guess: $18.38 Truth: $17.99 Error: $0.39 SLE: 0.00 Item: BOTNA Range Hood Gre...
# 104: Guess: $13.55 Truth: $7.99 Error: $5.56 SLE: 0.23 Item: Milk Frothing Pitche...
# 105: Guess: $14.31 Truth: $28.99 Error: $14.68 SLE: 0.45 Item: 1040 Replacement Wic...
# 106: Guess: $20.48 Truth: $12.07 Error: $8.41 SLE: 0.25 Item: Stanco Gas Range Dri...
# 107: Guess: $15.43 Truth: $18.99 Error: $3.56 SLE: 0.04 Item: Dampp Chaser Piano H...
# 108: Guess: $9.06 Truth: $9.99 Error: $0.93 SLE: 0.01 Item: Gardens Light Switch...
# 109: Guess: $25.75 Truth: $29.99 Error: $4.24 SLE: 0.02 Item: Waterspecialist Repl...
# 110: Guess: $18.39 Truth: $9.99 Error: $8.40 SLE: 0.32 Item: Upgraded Stove Knob,...
# 111: Guess: $18.45 Truth: $31.69 Error: $13.24 SLE: 0.27 Item: 5-PACK Top Burner Co...
# 112: Guess: $19.00 Truth: $24.99 Error: $5.99 SLE: 0.07 Item: Large Capacity Egg H...
# 113: Guess: $19.12 Truth: $25.99 Error: $6.86 SLE: 0.09 Item: FireFly Home Stove T...
# 114: Guess: $14.28 Truth: $18.99 Error: $4.71 SLE: 0.07 Item: Annbully Cartoon USB...
# 115: Guess: $11.52 Truth: $9.99 Error: $1.53 SLE: 0.02 Item: Goldenvalueable 6 x ...
# 116: Guess: $38.81 Truth: $22.99 Error: $15.82 SLE: 0.26 Item: Blueangle Pink Hibis...
# 117: Guess: $178.75 Truth: $169.99 Error: $8.76 SLE: 0.00 Item: ROVSUN 13LBS Portabl...
# 118: Guess: $21.64 Truth: $36.99 Error: $15.35 SLE: 0.27 Item: 1-Year Warranty Drye...
# 119: Guess: $23.66 Truth: $33.99 Error: $10.33 SLE: 0.12 Item: ICEPURE Replacement ...
# 120: Guess: $52.00 Truth: $104.89 Error: $52.89 SLE: 0.48 Item: Whirlpool Water Inle...
# 121: Guess: $16.75 Truth: $19.98 Error: $3.23 SLE: 0.03 Item: Washing Machine Wate...
# 122: Guess: $11.69 Truth: $9.99 Error: $1.70 SLE: 0.02 Item: Sunflowers Refrigera...
# 123: Guess: $11.66 Truth: $28.10 Error: $16.44 SLE: 0.69 Item: General Electric Fro...
# 124: Guess: $18.34 Truth: $27.50 Error: $9.16 SLE: 0.15 Item: Supco Refrigerator W...
# 125: Guess: $18.38 Truth: $36.99 Error: $18.62 SLE: 0.45 Item: HASMX Dishwasher Cut...
# 126: Guess: $24.00 Truth: $19.84 Error: $4.16 SLE: 0.03 Item: Whirlpool Range Surf...
# 127: Guess: $14.20 Truth: $24.99 Error: $10.79 SLE: 0.29 Item: 950S - Compatible wi...
# 128: Guess: $178.75 Truth: $169.99 Error: $8.76 SLE: 0.00 Item: WAFIET 12 Inch Gas C...
# 129: Guess: $19.09 Truth: $19.99 Error: $0.90 SLE: 0.00 Item: Reusable Vertuo Caps...
# 130: Guess: $34.81 Truth: $25.95 Error: $8.86 SLE: 0.08 Item: Coffee Filter Holder...
# 131: Guess: $109.38 Truth: $39.96 Error: $69.41 SLE: 0.98 Item: Star Deflector-Burne...
# 132: Guess: $11.01 Truth: $15.99 Error: $4.98 SLE: 0.12 Item: General Electric Ran...
# 133: Guess: $26.53 Truth: $39.99 Error: $13.46 SLE: 0.16 Item: WiFi Temperature Sen...
# 134: Guess: $18.97 Truth: $21.53 Error: $2.56 SLE: 0.01 Item: KITCHEN BASICS 101 1...
# 135: Guess: $22.50 Truth: $26.99 Error: $4.49 SLE: 0.03 Item: Dryer Heating Elemen...
# 136: Guess: $27.31 Truth: $43.99 Error: $16.68 SLE: 0.21 Item: Samsung HAF-CIN EXP ...
# 137: Guess: $10.98 Truth: $9.41 Error: $1.57 SLE: 0.02 Item: HQRP 3-Pack Wick Fil...
# 138: Guess: $13.22 Truth: $8.99 Error: $4.23 SLE: 0.12 Item: Reusable K Cups For ...
# 139: Guess: $58.09 Truth: $61.51 Error: $3.42 SLE: 0.00 Item: for GE Icemaker Refr...
# 140: Guess: $55.69 Truth: $122.30 Error: $66.61 SLE: 0.60 Item: Whirlpool Inlet Valv...
# 141: Guess: $10.97 Truth: $14.89 Error: $3.92 SLE: 0.08 Item: 100 UNIVERSAL Round ...
# 142: Guess: $11.66 Truth: $39.99 Error: $28.33 SLE: 1.38 Item: TRUE 811502 Nozzle a...
# 143: Guess: $13.56 Truth: $17.90 Error: $4.34 SLE: 0.07 Item: Dianoo Espresso Stea...
# 171: Guess: $14.23 Truth: $47.86 Error: $33.63 SLE: 1.36 Item: GE Igniter for Gas B...
# 172: Guess: $24.00 Truth: $34.45 Error: $10.45 SLE: 0.12 Item: General Electric Dry...
# 173: Guess: $7.89 Truth: $7.99 Error: $0.10 SLE: 0.00 Item: 312959 Dryer Belt Re...
# 174: Guess: $19.00 Truth: $27.99 Error: $8.99 SLE: 0.14 Item: 5-Pack Replacement E...
# 175: Guess: $57.94 Truth: $117.99 Error: $60.05 SLE: 0.49 Item: OEM Samsung Refriger...
# 176: Guess: $341.75 Truth: $989.99 Error: $648.24 SLE: 1.13 Item: vevor 24 Undercounte...
# 177: Guess: $19.12 Truth: $18.99 Error: $0.14 SLE: 0.00 Item: Reusable Vertuo Caps...
# 178: Guess: $56.53 Truth: $164.98 Error: $108.45 SLE: 1.12 Item: 32 x 30 2.5 Heavy Du...
# 179: Guess: $18.09 Truth: $19.36 Error: $1.27 SLE: 0.00 Item: Fluidmaster 9WM60 No...
# 180: Guess: $14.33 Truth: $16.00 Error: $1.67 SLE: 0.01 Item: AYZE Electric Restri...
# 181: Guess: $23.97 Truth: $21.40 Error: $2.57 SLE: 0.01 Item: Whirlpool Door Handl...
# 182: Guess: $18.45 Truth: $46.99 Error: $28.54 SLE: 0.82 Item: Upgraded Dryer Repai...
# 183: Guess: $19.00 Truth: $13.69 Error: $5.31 SLE: 0.10 Item: Camco 00553 8 GE/Hot...
# 184: Guess: $14.38 Truth: $22.72 Error: $8.34 SLE: 0.19 Item: GE Part Number KNOB ...
# 185: Guess: $35.97 Truth: $105.13 Error: $69.16 SLE: 1.11 Item: Manitowoc Ice Curtai...
# 186: Guess: $19.98 Truth: $32.50 Error: $12.52 SLE: 0.22 Item: Heating Element ( Re...
# 187: Guess: $18.00 Truth: $114.60 Error: $96.60 SLE: 3.26 Item: Vulcan Hart Thermo
# P...
# 188: Guess: $35.00 Truth: $84.96 Error: $49.96 SLE: 0.76 Item: Turbo Air Thermostat...
# 189: Guess: $66.38 Truth: $83.40 Error: $17.03 SLE: 0.05 Item: Frigidaire Dispenser...
# 190: Guess: $8.36 Truth: $9.99 Error: $1.63 SLE: 0.03 Item: Splutch Cam Kit Repl...
# 191: Guess: $9.08 Truth: $9.49 Error: $0.41 SLE: 0.00 Item: newlifeapp Dryer The...
# 192: Guess: $10.88 Truth: $29.99 Error: $19.11 SLE: 0.92 Item: Upgraded Dryer Rear ...
# 193: Guess: $16.73 Truth: $13.57 Error: $3.16 SLE: 0.04 Item: 2 Pack Top Burner Sp...
# 194: Guess: $18.36 Truth: $19.96 Error: $1.60 SLE: 0.01 Item: Washer Drain Pump Mo...
# 195: Guess: $22.67 Truth: $56.99 Error: $34.32 SLE: 0.80 Item: New-Refrigerator Ice...
# 196: Guess: $11.66 Truth: $16.37 Error: $4.71 SLE: 0.10 Item: Whirlpool Adjuster
# P...
# 197: Guess: $18.53 Truth: $19.99 Error: $1.46 SLE: 0.01 Item: Nispira Replacement ...
# 198: Guess: $23.62 Truth: $37.98 Error: $14.35 SLE: 0.21 Item: Mist Water Filter Re...
# 199: Guess: $35.47 Truth: $34.79 Error: $0.68 SLE: 0.00 Item: UPGRADE Refrigerator...
# 200: Guess: $9.11 Truth: $8.39 Error: $0.72 SLE: 0.01 Item: DPD Washer Lid Switc...
# 201: Guess: $57.00 Truth: $117.86 Error: $60.86 SLE: 0.51 Item: GENUINE Frigidaire B...
# 202: Guess: $11.51 Truth: $15.99 Error: $4.48 SLE: 0.09 Item: Anti Vibration Pads ...
# 203: Guess: $10.86 Truth: $10.99 Error: $0.13 SLE: 0.00 Item: Dryer Drum Support R...
# 204: Guess: $11.67 Truth: $24.43 Error: $12.76 SLE: 0.49 Item: Whirlpool 279816 Dry...
# 205: Guess: $26.66 Truth: $426.98 Error: $400.32 SLE: 7.50 Item: Empava 36 500 CFM Is...
# 206: Guess: $25.78 Truth: $39.99 Error: $14.21 SLE: 0.18 Item: SpiroPure NSF Certif...
# 207: Guess: $10.99 Truth: $26.99 Error: $16.00 SLE: 0.72 Item: Replacement for Jenn...
# 208: Guess: $36.03 Truth: $138.69 Error: $102.66 SLE: 1.76 Item: GE Genuine OEM Dampe...
# 209: Guess: $11.65 Truth: $13.97 Error: $2.32 SLE: 0.03 Item: Dryer Thermal Fuse T...
# 210: Guess: $21.88 Truth: $21.99 Error: $0.11 SLE: 0.00 Item: 2-Pack Replacement f...
# 211: Guess: $10.91 Truth: $18.88 Error: $7.97 SLE: 0.26 Item: Terminal Block Assem...
# 212: Guess: $36.00 Truth: $18.41 Error: $17.59 SLE: 0.42 Item: Whirlpool 308180 Bak...
# 213: Guess: $10.95 Truth: $9.95 Error: $1.00 SLE: 0.01 Item: LG Sensor Kenmore Wa...
# 214: Guess: $9.09 Truth: $18.00 Error: $8.91 SLE: 0.40 Item: Compatible Drum Belt...
# 215: Guess: $19.06 Truth: $33.95 Error: $14.89 SLE: 0.31 Item: Whirlpool Dryer Liqu...
# 216: Guess: $19.03 Truth: $42.95 Error: $23.92 SLE: 0.62 Item: MCGILL Replacement B...
# 217: Guess: $18.42 Truth: $59.99 Error: $41.57 SLE: 1.31 Item: New Upgraded Refrige...
# 218: Guess: $29.28 Truth: $55.58 Error: $26.30 SLE: 0.39 Item: TRUE 810719 Black Ga...
# 219: Guess: $29.66 Truth: $15.10 Error: $14.56 SLE: 0.41 Item: LG Genuine OEM Drain...
# 220: Guess: $25.16 Truth: $45.99 Error: $20.83 SLE: 0.34 Item: Waterspecialist Refr...
# 221: Guess: $24.80 Truth: $60.14 Error: $35.34 SLE: 0.74 Item: GlobPro Washer Water...
# 222: Guess: $22.92 Truth: $45.99 Error: $23.07 SLE: 0.46 Item: AQUA CREST 847200 Re...
# 223: Guess: $24.00 Truth: $16.24 Error: $7.76 SLE: 0.14 Item: Frigidaire Frigidare...
# 224: Guess: $11.62 Truth: $31.99 Error: $20.36 SLE: 0.92 Item: Supplying Demand Clo...
# 225: Guess: $15.23 Truth: $34.00 Error: $18.77 SLE: 0.59 Item: Whole Parts Dryer Pu...
# 226: Guess: $19.05 Truth: $26.99 Error: $7.94 SLE: 0.11 Item: i Cafillas Refillabl...
# 227: Guess: $11.62 Truth: $15.39 Error: $3.77 SLE: 0.07 Item: Thermostat
# Brand new...
# 228: Guess: $19.97 Truth: $27.77 Error: $7.80 SLE: 0.10 Item: Beaquicy Oven Bake E...
# 229: Guess: $18.00 Truth: $26.08 Error: $8.08 SLE: 0.13 Item: Whirlpool 661570 Bel...
# 230: Guess: $25.25 Truth: $18.99 Error: $6.26 SLE: 0.07 Item: iFillMug 33 Pack for...
# 231: Guess: $25.67 Truth: $159.18 Error: $133.51 SLE: 3.21 Item: Frigidaire Freezer D...
# 232: Guess: $26.41 Truth: $34.95 Error: $8.54 SLE: 0.07 Item: New York Air Airplan...
# 233: Guess: $21.69 Truth: $25.19 Error: $3.50 SLE: 0.02 Item: Amazon Basics Replac...
# 234: Guess: $9.05 Truth: $19.51 Error: $10.46 SLE: 0.51 Item: Upgraded Dishrack St...
# 235: Guess: $39.00 Truth: $37.45 Error: $1.55 SLE: 0.00 Item: Sportman Pastoral St...
# 236: Guess: $31.94 Truth: $29.99 Error: $1.95 SLE: 0.00 Item: Motor OEM Mania New ...
# 237: Guess: $79.19 Truth: $163.56 Error: $84.37 SLE: 0.52 Item: Refrigerator Ice Mak...
# 238: Guess: $14.25 Truth: $27.00 Error: $12.75 SLE: 0.37 Item: Appliance Slide for ...
# 239: Guess: $7.00 Truth: $5.99 Error: $1.01 SLE: 0.02 Item: Lower Dishwasher Whe...
# 240: Guess: $9.08 Truth: $6.64 Error: $2.44 SLE: 0.08 Item: Gas Female Cap ORIFI...
# 241: Guess: $10.98 Truth: $26.04 Error: $15.06 SLE: 0.66 Item: 9pcs Silicon Rubber ...
# 242: Guess: $10.01 Truth: $13.79 Error: $3.78 SLE: 0.09 Item: Supplying Demand Clo...
# 243: Guess: $67.38 Truth: $78.98 Error: $11.61 SLE: 0.02 Item: General Electric Ref...
# 244: Guess: $19.06 Truth: $27.99 Error: $8.93 SLE: 0.14 Item: i Cafilas New Lid St...
# 245: Guess: $11.64 Truth: $14.99 Error: $3.35 SLE: 0.06 Item: GHM Humidifier Repla...
# 246: Guess: $89.81 Truth: $50.25 Error: $39.56 SLE: 0.33 Item: Manitowoc Ice Water ...
# 247: Guess: $21.66 Truth: $101.36 Error: $79.70 SLE: 2.27 Item: General Electric Doo...
# 248: Guess: $12.02 Truth: $4.98 Error: $7.04 SLE: 0.60 Item: Kitchen Stove Gap Co...
# 249: Guess: $9.14 Truth: $9.89 Error: $0.75 SLE: 0.01 Item: Washer & Dryer Lid S...
# 250: Guess: $18.55 Truth: $27.99 Error: $9.44 SLE: 0.16 Item: Nispira Humidifier W...
